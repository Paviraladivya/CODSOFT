# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns = None

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df['Amount']=sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df = df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
df.shape
# Out:
# (284807, 30)

# %%
df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()

# %%
print("After removing duplicate values shape of dataset is =", df.shape)
# Out:
# After removing duplicate values shape of dataset is = (275663, 30)

# %%
print("The duplicate values is = ", 284807-275663)
# Out:
# The duplicate values is =  9144

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sb

# %%
sb.countplot(df['Class'], color = 'r')
# Out:
# <Axes: ylabel='count'>

# %%
normal = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample = normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_df = pd.concat([normal_sample,fraud])

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_df.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 130144 -0.405975  0.437799  2.286306 -1.519525 -0.346338 -0.615866  0.667473
# 241789  1.995080 -0.626963 -0.632030  0.143035 -0.367025  0.469797 -0.915626
# 202196  0.005541 -0.280227  1.041896 -1.508810 -0.044395  0.237427  0.212605
# 111501 -0.675034  1.209240  1.601979 -0.004827 -0.245757 -1.122692  0.675291
# 43157   1.159803  0.011840  1.025612  1.350963 -0.809957 -0.302297 -0.380594
#
#               V8        V9       V10       V11       V12       V13       V14  \
# 130144 -0.706758  1.932935 -0.361667 -0.171294  0.522758  0.466470 -1.158723
# 241789  0.300138  1.242804  0.209680 -0.102254  0.073952 -1.168153  0.153587
# 202196 -0.332108 -0.266492  0.926868  0.681051  0.976155  1.485574 -0.943731
# 111501 -0.075128 -0.223819  0.000969 -0.083945  0.071074 -0.024138  0.091466
# 43157   0.004566  0.742218 -0.181267 -0.779963  0.574586  0.265352 -0.330410
#
# ...

# %%
new_df = pd.concat([normal_sample,fraud],ignore_index = True)

# %%
new_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.405975  0.437799  2.286306 -1.519525 -0.346338 -0.615866  0.667473
# 1  1.995080 -0.626963 -0.632030  0.143035 -0.367025  0.469797 -0.915626
# 2  0.005541 -0.280227  1.041896 -1.508810 -0.044395  0.237427  0.212605
# 3 -0.675034  1.209240  1.601979 -0.004827 -0.245757 -1.122692  0.675291
# 4  1.159803  0.011840  1.025612  1.350963 -0.809957 -0.302297 -0.380594
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.706758  1.932935 -0.361667 -0.171294  0.522758  0.466470 -1.158723
# 1  0.300138  1.242804  0.209680 -0.102254  0.073952 -1.168153  0.153587
# 2 -0.332108 -0.266492  0.926868  0.681051  0.976155  1.485574 -0.943731
# 3 -0.075128 -0.223819  0.000969 -0.083945  0.071074 -0.024138  0.091466
# 4  0.004566  0.742218 -0.181267 -0.779963  0.574586  0.265352 -0.330410
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_df.tail()
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 941 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 942  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 943 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 944 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 945  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#            V8        V9       V10       V11       V12       V13       V14  \
# 941  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123 -6.665177
# 942  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532 -5.210141
# 943  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950 -4.057162
# 944  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455 -6.416628
# 945 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428 -1.948883
#
# ...

# %%
x = new_df.drop('Class',axis=1)
y = new_df['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9157894736842105

# %%
from sklearn.metrics import precision_score, recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.93

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9207920792079208

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8789473684210526

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8761904761904762

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.888888888888889

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9157894736842105

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9387755102040817

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.92

# %%
final_result = pd.DataFrame({'Model':['LR','DT','RF'],
                            "ACC":[accuracy_score(y_test,y_pred1)*100,
                                   accuracy_score(y_test,y_pred2)*100,
                                   accuracy_score(y_test,y_pred3)*100
                                  ]})

# %%
final_result
# Out:
#   Model        ACC
# 0    LR  91.578947
# 1    DT  87.894737
# 2    RF  91.578947

# %%
sb.barplot(final_result['Models',ylabel'ACC'])
